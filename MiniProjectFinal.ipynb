# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemant-1Kumar/SIH/blob/main/MiniProjectFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("birendranathnandi/indian-cattle-and-buffalo-breeds-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 260M/260M [00:01<00:00, 149MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2

# %%
import kagglehub, os

path = kagglehub.dataset_download("birendranathnandi/indian-cattle-and-buffalo-breeds-dataset")
print("Dataset path:", path)

# show first few folders and files
for root, dirs, files in os.walk(path):
    print("📁 Folder:", root)
    print("Subfolders:", dirs)
    print("Files:", files[:5])
    break
# Out:
# Dataset path: /root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2
# 📁 Folder: /root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2
# Subfolders: ['IndianCattleBuffaloeBreeds-Dataset']
# Files: []

# %%
import os

for root, dirs, files in os.walk(path):
    print("📁 Folder:", root)
    print("Subfolders:", dirs)
    print("Files:", files[:5])
    break
# Out:
# 📁 Folder: /root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2
# Subfolders: ['IndianCattleBuffaloeBreeds-Dataset']
# Files: []

# %%
import os

path = "/root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2/IndianCattleBuffaloeBreeds-Dataset"

for root, dirs, files in os.walk(path):
    print("📁", root)
    print("📂", dirs)
    print("📸", files[:5])
    print("-" * 60)
# Out:
# 📁 /root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2/IndianCattleBuffaloeBreeds-Dataset
# 📂 ['breeds']
# 📸 []
# ------------------------------------------------------------
# 📁 /root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2/IndianCattleBuffaloeBreeds-Dataset/breeds
# 📂 ['test', 'train']
# 📸 []
# ------------------------------------------------------------
# 📁 /root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2/IndianCattleBuffaloeBreeds-Dataset/breeds/test
# ...

# %%
import os

base = "/root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2/IndianCattleBuffaloeBreeds-Dataset"
os.listdir(base)
# Out:
# ['breeds']

# %%
import os

base = "/root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2/IndianCattleBuffaloeBreeds-Dataset/breeds"

os.listdir(base)
# Out:
# ['test', 'train']

# %%
base = "/root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2/IndianCattleBuffaloeBreeds-Dataset/breeds"

train_path = f"{base}/train"
test_path  = f"{base}/test"

print(os.listdir(train_path))
print(os.listdir(test_path))
# Out:
# ['Vechur', 'Gir', 'Rathi', 'Jaffrabadi', 'Toda', 'Hallikar', 'Surti', 'Murrah', 'Khillari', 'Kenkatha', 'Mehsana', 'Nagori', 'Sahiwal', 'Amritmahal', 'Nili_Ravi', 'Dangi', 'Brown_Swiss', 'Alambadi', 'Hariana', 'Tharparkar', 'Krishna_Valley', 'Banni', 'Nagpuri', 'Ayrshire', 'Nimari', 'Jersey', 'Bargur', 'Holstein_Friesian', 'Guernsey', 'Red_Sindhi', 'Kankrej', 'Malnad_gidda', 'Pulikulam', 'Kherigarh', 'Ongole', 'Deoni', 'Kangayam', 'Kasargod', 'Umblachery', 'Red_Dane', 'Bhadawari']
# ['Vechur', 'Gir', 'Rathi', 'Jaffrabadi', 'Toda', 'Hallikar', 'Surti', 'Murrah', 'Khillari', 'Kenkatha', 'Mehsana', 'Nagori', 'Sahiwal', 'Amritmahal', 'Nili_Ravi', 'Dangi', 'Brown_Swiss', 'Alambadi', 'Hariana', 'Tharparkar', 'Krishna_Valley', 'Banni', 'Nagpuri', 'Ayrshire', 'Nimari', 'Jersey', 'Bargur', 'Holstein_Friesian', 'Guernsey', 'Red_Sindhi', 'Kankrej', 'Malnad_gidda', 'Pulikulam', 'Kherigarh', 'Ongole', 'Deoni', 'Kangayam', 'Kasargod', 'Umblachery', 'Red_Dane', 'Bhadawari']

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from PIL import Image

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix

# %%
train_dir = "breeds/train"
test_dir = "breeds/test"

# %%
train_dir = "/root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2/IndianCattleBuffaloeBreeds-Dataset/breeds/train"
test_dir  = "/root/.cache/kagglehub/datasets/birendranathnandi/indian-cattle-and-buffalo-breeds-dataset/versions/2/IndianCattleBuffaloeBreeds-Dataset/breeds/test"


def count_images(path):
    class_counts = {}
    for cls in sorted(os.listdir(path)):
        cls_path = os.path.join(path, cls)
        if os.path.isdir(cls_path):
            class_counts[cls] = len(os.listdir(cls_path))
    return class_counts

train_counts = count_images(train_dir)
test_counts = count_images(test_dir)

print("\nTRAIN DISTRIBUTION:\n", train_counts)
print("\nTEST DISTRIBUTION:\n", test_counts)

# Plot
plt.figure(figsize=(18, 6))
plt.xticks(rotation=90)
sns.barplot(x=list(train_counts.keys()), y=list(train_counts.values()))
plt.title("Train Class Distribution")
plt.xlabel("Breed")
plt.ylabel("Image Count")
plt.show()
# Out:
# TRAIN DISTRIBUTION:
#  {'Alambadi': 99, 'Amritmahal': 94, 'Ayrshire': 234, 'Banni': 109, 'Bargur': 94, 'Bhadawari': 86, 'Brown_Swiss': 225, 'Dangi': 82, 'Deoni': 99, 'Gir': 372, 'Guernsey': 119, 'Hallikar': 186, 'Hariana': 129, 'Holstein_Friesian': 328, 'Jaffrabadi': 102, 'Jersey': 203, 'Kangayam': 91, 'Kankrej': 179, 'Kasargod': 95, 'Kenkatha': 55, 'Kherigarh': 36, 'Khillari': 113, 'Krishna_Valley': 136, 'Malnad_gidda': 107, 'Mehsana': 95, 'Murrah': 173, 'Nagori': 89, 'Nagpuri': 187, 'Nili_Ravi': 89, 'Nimari': 84, 'Ongole': 191, 'Pulikulam': 125, 'Rathi': 149, 'Red_Dane': 167, 'Red_Sindhi': 166, 'Sahiwal': 439, 'Surti': 64, 'Tharparkar': 217, 'Toda': 124, 'Umblachery': 76, 'Vechur': 140}
#
# TEST DISTRIBUTION:
# ...

# %%
import random

def show_sample_images(base_path):
    classes = os.listdir(base_path)
    plt.figure(figsize=(14, 14))

    for i in range(16):
        cls = random.choice(classes)
        cls_path = os.path.join(base_path, cls)
        img = random.choice(os.listdir(cls_path))
        img_path = os.path.join(cls_path, img)

        plt.subplot(4, 4, i+1)
        plt.imshow(Image.open(img_path))
        plt.title(cls)
        plt.axis("off")

    plt.show()

show_sample_images(train_dir)

# %%
def check_corrupted_images(base_path):
    corrupted = []
    for cls in os.listdir(base_path):
        cls_path = os.path.join(base_path, cls)
        for img in os.listdir(cls_path):
            img_path = os.path.join(cls_path, img)
            try:
                Image.open(img_path).verify()
            except:
                corrupted.append(img_path)

    return corrupted

bad = check_corrupted_images(train_dir)
print("CORRUPTED IMAGES:", bad)
# Out:
# CORRUPTED IMAGES: []

# %%
IMG_SIZE = 224
BATCH_SIZE = 32

train_gen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.15,
    zoom_range=0.15,
    rotation_range=15,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
)

test_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True
)

test_data = test_gen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_data.class_indices)
# Out:
# Found 5948 images belonging to 41 classes.
# Found 5948 images belonging to 41 classes.

# %%
base = MobileNetV2(include_top=False, input_shape=(224, 224, 3), weights="imagenet")
base.trainable = False   # freeze layers

x = GlobalAveragePooling2D()(base.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base.input, outputs=output)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0008),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ...

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3),
    ModelCheckpoint("best_model.keras", monitor="val_accuracy", save_best_only=True)
]

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3),
    ModelCheckpoint("best_model.keras", monitor="val_accuracy", save_best_only=True)
]

# %%
history = model.fit(
    train_data,
    validation_data=test_data,
    epochs=40,
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 319s 2s/step - accuracy: 0.1113 - loss: 3.6805 - val_accuracy: 0.3216 - val_loss: 2.4514 - learning_rate: 8.0000e-04
# Epoch 2/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 363s 2s/step - accuracy: 0.2852 - loss: 2.5899 - val_accuracy: 0.3811 - val_loss: 2.1751 - learning_rate: 8.0000e-04
# Epoch 3/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 409s 2s/step - accuracy: 0.3417 - loss: 2.3130 - val_accuracy: 0.4285 - val_loss: 2.0088 - learning_rate: 8.0000e-04
# Epoch 4/40
# ...

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy Curve")
plt.legend(["Train", "Validation"])

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Loss Curve")
plt.legend(["Train", "Validation"])

plt.show()

# %%
test_loss, test_acc = model.evaluate(test_data)
print("TEST ACC:", test_acc)
print("TEST LOSS:", test_loss)
# Out:
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 139s 745ms/step - accuracy: 0.6713 - loss: 1.1416
# TEST ACC: 0.6578682065010071
# TEST LOSS: 1.1665366888046265

# %%
y_true = test_data.classes
y_pred = model.predict(test_data)
y_pred = np.argmax(y_pred, axis=1)

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=test_data.class_indices.keys()))
# Out:
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 141s 752ms/step
#
# Classification Report:
#
#                    precision    recall  f1-score   support
#
#          Alambadi       0.86      0.48      0.62        99
#        Amritmahal       0.48      0.74      0.58        94
#          Ayrshire       0.79      0.76      0.78       234
#             Banni       0.40      0.75      0.52       109
#            Bargur       0.97      0.74      0.84        94
#         Bhadawari       0.64      0.40      0.49        86
#       Brown_Swiss       0.68      0.79      0.73       225
#             Dangi       0.93      0.80      0.86        82
#             Deoni       0.87      0.48      0.62        99
#               Gir       0.70      0.67      0.68       372
#          Guernsey       0.67      0.82      0.74       119
#          Hallikar       0.63      0.61      0.62       186
#           Hariana       0.57      0.64      0.60       129
# Holstein_Friesian       0.81      0.91      0.86       328
# ...

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(18, 14))
sns.heatmap(cm, annot=False, cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'best_model.keras',
#  'image4.jpg',
#  'image2.jpg',
#  'image3.jpg',
#  'sample_data']

# %%
import tensorflow as tf
import numpy as np
import cv2

# ------------------------------
# 1. Load model
# ------------------------------
model = tf.keras.models.load_model("best_model.keras")

# ------------------------------
# 2. Class labels
# ------------------------------
class_names = [
    'Hariana','Vechur','Kangayam','Ayrshire','Red_Dane','Rathi','Umblachery','Gir',
    'Murrah','Krishna_Valley','Red_Sindhi','Bhadawari','Malnad_gidda','Dangi',
    'Nili_Ravi','Brown_Swiss','Tharparkar','Deoni','Jersey','Holstein_Friesian',
    'Nagori','Surti','Hallikar','Nagpuri','Alambadi','Sahiwal','Pulikulam',
    'Ongole','Kenkatha','Kankrej','Nimari','Khillari','Bargur','Jaffrabadi',
    'Banni','Amritmahal','Toda','Mehsana','Kherigarh','Kasargod','Guernsey'
]

# ------------------------------
# 3. Function to predict image
# ------------------------------
def predict_image(img_path):
    img = tf.keras.utils.load_img(img_path, target_size=(224, 224))
    img_array = tf.keras.utils.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    pred = model.predict(img_array)
    class_id = np.argmax(pred)
    confidence = np.max(pred)

    print("Predicted Breed:", class_names[class_id])
    print("Confidence    :", round(confidence * 100, 2), "%")

# ------------------------------
# 4. Test any image
# ------------------------------
predict_image("image2.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 797ms/step
# Predicted Breed: Dangi
# Confidence    : 91.82 %

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Load model
model = tf.keras.models.load_model("best_model.keras")

# Class labels
class_names = [
    'Hariana','Vechur','Kangayam','Ayrshire','Red_Dane','Rathi','Umblachery','Gir',
    'Murrah','Krishna_Valley','Red_Sindhi','Bhadawari','Malnad_gidda','Dangi',
    'Nili_Ravi','Brown_Swiss','Tharparkar','Deoni','Jersey','Holstein_Friesian',
    'Nagori','Surti','Hallikar','Nagpuri','Alambadi','Sahiwal','Pulikulam',
    'Ongole','Kenkatha','Kankrej','Nimari','Khillari','Bargur','Jaffrabadi',
    'Banni','Amritmahal','Toda','Mehsana','Kherigarh','Kasargod','Guernsey'
]

# ===========================
# Load Test Image
# ===========================
img_path = "/content/image2.jpg"   # <-- change your image path here

image = cv2.imread(img_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis("off")
plt.show()

# ===========================
# Prepare Image
# ===========================
img_resized = cv2.resize(image_rgb, (224, 224))
img_array = img_resized / 255.0
img_array = np.expand_dims(img_array, axis=0)   # Shape: (1, 224, 224, 3)

# ===========================
# Prediction
# ===========================
prediction = model.predict(img_array)[0]
class_id = np.argmax(prediction)
confidence = prediction[class_id] * 100

print("===================================")
print(f"Predicted Breed : {class_names[class_id]}")
print(f"Confidence      : {confidence:.2f}%")
print("===================================")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 787ms/step
# ...
# Predicted Breed : Dangi
# Confidence      : 85.96%
# ...
